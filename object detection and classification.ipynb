# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from imageai.Detection import ObjectDetection
import os

# %% [markdown]
# ## EXAMPLE

# %%
image_path='C:\\Users\\Administrator\\Desktop\\Extra\\competition\\maxresdefault.jpg'
image=plt.imread(image_path)
plt.imshow(image)

# %%
execution_path=os.getcwd()
detector=ObjectDetection()
detector.setModelTypeAsRetinaNet()
detector.setModelPath(os.path.join(execution_path,"resnet50_coco_best_v2.0.1.h5"))
detector.loadModel()

# %%
custom_objects=detector.CustomObjects(car=True)
detections=detector.detectCustomObjectsFromImage(input_image=image_path,
                                                 output_image_path=os.path.join(execution_path ,"image_new.png"),
                                                 custom_objects=custom_objects,
                                                 minimum_percentage_probability=65)

# %%
from IPython.display import Image
Image('image_new.png')

# %%
labels=pd.read_excel('C:/Users/Administrator/Desktop/Extra/competition/training_data/labels.xlsx')

# %%
# labels=labels.drop(['Source.Name','source.annotation'],axis=1)

# %%
# labels=labels.replace({1:'car',2:'Swimming pool'})

# %%
# labels.to_excel('labels.xlsx',index=False)

# %%
labels['path']=0
labels.head()
# Out:
#         filename  size.width  size.height  size.depth object.name  path
# 0  000000000.jpg         224          224           3         car     0
# 1  000000000.jpg         224          224           3         car     0
# 2  000000000.jpg         224          224           3         car     0
# 3  000000000.jpg         224          224           3         car     0
# 4  000000001.jpg         224          224           3         car     0

# %%
path='C:\\Users\\Administrator\\Desktop\\Extra\\competition\\training_data\\images'

# %%
filenames=[]
for i in range(len(labels['filename'])):
    filenames.append(path+'\\'+labels['filename'][i])

# %%
labels['path']=filenames
labels.head()
# Out:
#         filename  size.width  size.height  size.depth object.name  \
# 0  000000000.jpg         224          224           3         car
# 1  000000000.jpg         224          224           3         car
# 2  000000000.jpg         224          224           3         car
# 3  000000000.jpg         224          224           3         car
# 4  000000001.jpg         224          224           3         car
#
#                                                 path
# 0  C:\Users\Administrator\Desktop\Extra\competiti...
# 1  C:\Users\Administrator\Desktop\Extra\competiti...
# 2  C:\Users\Administrator\Desktop\Extra\competiti...
# 3  C:\Users\Administrator\Desktop\Extra\competiti...
# 4  C:\Users\Administrator\Desktop\Extra\competiti...

# %%
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D,M

# %%
plt.figure(figsize=(10,5))
image=plt.imread(labels.path[0])
plt.imshow(image)
